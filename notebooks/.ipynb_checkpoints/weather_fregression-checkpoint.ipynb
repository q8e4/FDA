# %%
getwd()
# Out:
# [1] "/home/kaliyev/FDA review/notebooks"

# %%
dta <- read.csv("../weather_data/smooth_x.csv", header = TRUE)

x <- dta
y <- read.csv("../weather_data/smooth_y.csv", header = TRUE)

tt <- seq(0, 1, length.out = 365)

head(dta, n = 5)
# Out:
#   X0.0      X0.0027472527472527475 X0.005494505494505495 X0.008241758241758242
# 1 -3.660400 -3.736265              -3.809357             -3.879924
# 2 -5.404007 -5.500738              -5.592125             -5.678333
# 3 -4.412640 -4.527858              -4.639533             -4.747820
# 4 -2.494160 -2.576691              -2.655288             -2.730147
# 5 -7.013178 -7.138611              -7.257962             -7.371330
#   X0.01098901098901099 X0.013736263736263736 X0.016483516483516484
# 1 -3.948213            -4.014470             -4.078931
# 2 -5.759543            -5.835944             -5.907736
# 3 -4.852886            -4.954906             -5.054055
# 4 -2.801470            -2.869460             -2.934320
# 5 -7.478835            -7.580618             -7.676836
#   X0.019230769230769232 X0.02197802197802198 X0.024725274725274724 ⋯
# 1 -4.141824             -4.203363            -4.263747             ⋯
# 2 -5.975125             -6.038320            -6.097531             ⋯
# 3 -5.150512             -5.244451            -5.336042             ⋯
# 4 -2.996249             -3.055438            -3.112069             ⋯
# 5 -7.767661             -7.853279            -7.933883             ⋯
#   X0.9752747252747253 X0.978021978021978 X0.9807692307692307
# 1 -2.701643           -2.816414          -2.926677
# 2 -4.120340           -4.275157          -4.424150
# 3 -3.042695           -3.198180          -3.349582
# 4 -1.417847           -1.547623          -1.672327
# 5 -5.421050           -5.606988          -5.787319
#   X0.9835164835164835 X0.9862637362637363 X0.989010989010989
# 1 -3.032501           -3.133982           -3.231248
# 2 -4.567252           -4.704422           -4.835649
# 3 -3.496847           -3.639945           -3.778873
# 4 -1.791970           -1.906592           -2.016260
# 5 -5.961868           -6.130491           -6.293070
#   X0.9917582417582418 X0.9945054945054945 X0.9972527472527473 X1.0
# 1 -3.324449           -3.413761           -3.499380           -3.581517
# 2 -4.960945           -5.080352           -5.193936           -5.301784
# 3 -3.913657           -4.044343           -4.171003           -4.293731
# 4 -2.121063           -2.221113           -2.316543           -2.407503
# 5 -6.449516           -6.599768           -6.743794           -6.881589

# %%
# plot the functional data with colors corresponding to y
cx <- rainbow(12)[7:12]

matplot(tt, t(x), type="l", lty=1, col=cx, xlab="relative time", 
        ylab="temperature", bty="n", lwd=2)
# Out:
# plot without title

# %%
# Plot each row of y with a different color
matplot(tt, t(y), type="l", lty=1, col=cx, xlab="relative time", 
        ylab="precipitation", bty="n", lwd=2)
# Out:
# plot without title

# %%
x <- as.matrix(x) # 35 * 365
y <- as.matrix(y) # 35 * 365

# %%
set.seed(42)


train_ind <- sample(1:nrow(y), floor(0.8 * nrow(y)))  # Training indices
test_ind <- setdiff(1:nrow(y), train_ind)             


x_train <- x[train_ind, ]
y_train <- y[train_ind, ]
x_test <- x[test_ind, ]
y_test <- y[test_ind, ]

# x_train_centered <- t(apply(x_train, 1, function(row) scale(row, scale = FALSE)))
# x_test_centered <- t(apply(x_test, 1, function(row) scale(row, scale = FALSE)))


dim(x_train)
dim(y_train)
# Out:
# [1]  28 365
# [1]  28 365

# %%
# pffr Model Setup and Prediction
library(refund)

tt <- seq(0, 1, length.out = 365)

formula <- y_train ~ 1 + ffpc(x_train, yind = tt, xind = tt)

# Train the pffr model
model <- pffr(as.formula(formula), 
              algorithm = "bam" , 
              data = list(y_train = y_train, x_train = x_train))

summary(model)
# Out:
# Family: gaussian
# Link function: identity
#
# Formula:
# y_train ~ 1 + ffpc(x_train, yind = tt, xind = tt)
#
# Constant coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.29977    0.09792    33.7   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Smooth terms & functional coefficients:
#                          edf Ref.df       F p-value
# Intercept(yindex)     11.079 19.000   2.923  <2e-16 ***
# ffpc(x_train,tt,tt)1   8.000  8.000 388.481  <2e-16 ***
# ffpc(x_train,tt,tt)2   7.995  8.000 330.302  <2e-16 ***
# ffpc(x_train,tt,tt)3   7.948  7.976 115.353  <2e-16 ***
# ffpc(x_train,tt,tt)4   7.849  7.919  28.008  <2e-16 ***
# ffpc(x_train,tt,tt)5   6.983  7.396 131.897  <2e-16 ***
# ffpc(x_train,tt,tt)6   6.993  7.349 138.749  <2e-16 ***
# ffpc(x_train,tt,tt)7   6.386  6.806  14.257  <2e-16 ***
# ffpc(x_train,tt,tt)8   5.913  6.443  33.051  <2e-16 ***
# ffpc(x_train,tt,tt)9   6.691  7.135  36.435  <2e-16 ***
# ffpc(x_train,tt,tt)10  5.404  5.913  96.655  <2e-16 ***
# ffpc(x_train,tt,tt)11  4.790  5.363  77.716  <2e-16 ***
# ffpc(x_train,tt,tt)12  5.203  5.753 112.225  <2e-16 ***
# ffpc(x_train,tt,tt)13  6.272  6.704  47.356  <2e-16 ***
# ffpc(x_train,tt,tt)14  4.695  5.270  93.780  <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# R-sq.(adj) =  0.806   Deviance explained = 80.8%
# fREML score =  11449  Scale est. = 0.52139   n = 10220 (28 x 365)

# %%
matplot(tt, t(y_test[, 1]), type='l')
# Out:
# Error in matplot(tt, t(y_test[, 1]), type = "l"): 'x' and 'y' must have same number of rows
# Traceback:
#
# 1. matplot(tt, t(y_test[, 1]), type = "l")
# 2. stop("'x' and 'y' must have same number of rows")

# %%
predictions <- predict(model, newdata = list(x_train = x_test))

# %%
dim(predictions)
# Out:
# [1]   7 365

# %%
dim(y_test)
# Out:
# [1]   7 365

# %%
rmse <- sqrt(mean((y_test - predictions)^2))
print(rmse)
# Out:
# [1] 1.474882

# %%
# Assuming `tt` is the time vector and `y_test` is a matrix with observations
plot(tt, y_test[1, ], type = "l", col = "blue", lwd = 2,
     xlab = "relative time", ylab = "precipitation", xlim = c(0, 4))
# Out:
# plot without title

# %%
# Set plot dimensions in inches (for example, width = 12, height = 5)
par(pin = c(6, 5))

# Plot the first row of y_test with wider dimensions
matplot(tt, t(y_test), type = "l", lty = 1, col = cx, 
        xlab = "relative time", ylab = "precipitation", bty = "n", lwd = 2)

# Plot the first row of y_test with wider dimensions
matplot(tt, t(predictions), type = "l", lty = 1, col = cx, 
        xlab = "relative time", ylab = "precipitation", bty = "n", lwd = 2)
# Out:
# plot without title
# plot without title

# %%
# Assuming tt is a sequence of values with the same length as the number of columns in y_test
tt <- seq(1, ncol(y_test))  # or use specific x values if available

# Plot the first row of y_test
plot(tt, y_test[1, ], type = "l", col = "blue", lwd = 2,
     xlab = "relative time", ylab = "precipitation",
     main = "First Row of y_test")


# Plot the first row of y_test
plot(tt, predictions[1, ], type = "l", col = "blue", lwd = 2,
     xlab = "relative time", ylab = "precipitation",
     main = "First Row of y_test")
# Out:
# Plot with title “First Row of y_test”
# Plot with title “First Row of y_test”

# %%
gc()
# Out:
#        used    (Mb)  gc trigger (Mb)  max used (Mb)
# Ncells 2419952 129.3  4889217   261.2  3644859 194.7
# Vcells 4752816  36.3 38319405   292.4 59874069 456.9

# %%
set.seed(42)

dta1 <- read.csv("../weather_data/x.csv", header = TRUE)

x <- dta1
y <- read.csv("../weather_data/y.csv", header = TRUE)

tt <- seq(0, 1, length.out = 365)

x <- as.matrix(x) # 35 * 365
y <- as.matrix(y) # 35 * 365

train_ind <- sample(1:nrow(y), floor(0.8 * nrow(y)))  
test_ind <- setdiff(1:nrow(y), train_ind)             

x_train <- x[train_ind, ]
y_train <- y[train_ind, ]
x_test <- x[test_ind, ]
y_test <- y[test_ind, ]


dim(x_train)
dim(y_train)
# Out:
# [1]  28 365
# [1]  28 365

# %%
library(FDboost)

# Define the time vector for daily measurements over a normalized range (e.g., 0 to 1)
tt <- seq(0, 1, length.out = 365)

# Create the formula for functional principal component regression
formula <- y_train ~ 1 + ffpc(x_train, yind = tt, xind = tt)

# Initialize the FDboost model with time smoothing
print("Starting FDboost model...")
m <- FDboost(as.formula(formula),
             data = list(y_train = y_train, x_train = x_train),
             timeformula = ~ bbs(tt, df = 5),
             control=boost_control(mstop = 1000, nu = 0.1))

# Cross-validation for optimal mstop
set.seed(123)
appl1 <- applyFolds(m, folds = mboost::cv(rep(1, length(unique(m$id))), B = 5), grid = 1:1000)

plot(appl1)
m[mstop(m)]
# Out:
# [1] "Starting FDboost model..."
# Error in FDboost(as.formula(formula), data = list(y_train = y_train, x_train = x_train), : is.numeric(time) is not TRUE
# Traceback:
#
# 1. FDboost(as.formula(formula), data = list(y_train = y_train, x_train = x_train),
#  .     timeformula = ~bbs(tt, df = 5), control = boost_control(mstop = 1000,
#  .         nu = 0.1))
# 2. stopifnot(is.numeric(time))
